# %%
import os
from pathlib import Path

print("cwd: ", os.getcwd())
print("here: ", Path(".").resolve())
print(Path("../data/products.csv").resolve())
print(Path("../data/products.csv").exists())
# Out:
# cwd:  /Users/guypeer/nebius-academy-project/hw1/notebooks
# here:  /Users/guypeer/nebius-academy-project/hw1/notebooks
# /Users/guypeer/nebius-academy-project/hw1/data
# True
# /Users/guypeer/nebius-academy-project/hw1/data/products.csv
# False

# %%
import pandas as pd

df = pd.read_csv("../data/product_dataset.csv")

print("shape: ", df.shape, "\n")
df.head()
# Out:
# shape:  (50, 4)
#                       product_name  \
# 0              Apple iPhone 15 Pro
# 1         Samsung Galaxy S24 Ultra
# 2               Google Pixel 8 Pro
# 3       Sony WH‑1000XM5 Headphones
# 4  Bose QuietComfort Ultra Earbuds
#
#                               Product_attribute_list  \
# 0  features: A17 Pro chip, 120 Hz ProMotion displ...
# 1  features: 200 MP camera, S‑Pen support, 120 Hz...
# 2  features: Tensor G3 chip, Magic Eraser, 50 MP ...
# 3  features: active noise cancelling, 30 hr batte...
# 4  features: CustomTune sound calibration, ANC, I...
#
#                                      material                 warranty
# 0        titanium frame, Ceramic Shield glass  1‑year limited warranty
# 1  Armor Aluminum frame, Gorilla Glass Victus  1‑year limited warranty
# 2            matte glass back, aluminum frame  1‑year limited warranty
# 3                   synthetic leather earcups  1‑year limited warranty
# ...

# %%
df.columns.tolist()
# Out:
# ['product_name', 'Product_attribute_list', 'material', 'warranty']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_name            50 non-null     str
#  1   Product_attribute_list  50 non-null     str
#  2   material                50 non-null     str
#  3   warranty                50 non-null     str
# dtypes: str(4)
# memory usage: 1.7 KB

# %%
df.isna().sum()
# Out:
# product_name              0
# Product_attribute_list    0
# material                  0
# warranty                  0
# dtype: int64

# %%
df["product_name"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns.tolist()
# Out:
# ['product_name', 'Product_attribute_list', 'material', 'warranty']

# %%
[j for (i,j) in df.iterrows()][:5]
# Out:
# [product_name                                            Apple iPhone 15 Pro
#  Product_attribute_list    features: A17 Pro chip, 120 Hz ProMotion displ...
#  material                               titanium frame, Ceramic Shield glass
#  warranty                                            1‑year limited warranty
#  Name: 0, dtype: str,
#  product_name                                       Samsung Galaxy S24 Ultra
#  Product_attribute_list    features: 200 MP camera, S‑Pen support, 120 Hz...
#  material                         Armor Aluminum frame, Gorilla Glass Victus
#  warranty                                            1‑year limited warranty
#  Name: 1, dtype: str,
#  product_name                                             Google Pixel 8 Pro
#  Product_attribute_list    features: Tensor G3 chip, Magic Eraser, 50 MP ...
#  material                                   matte glass back, aluminum frame
#  warranty                                            1‑year limited warranty
# ...

# %%
[row for row in df.head().itertuples()]
# Out:
# [Pandas(Index=0, product_name='Apple iPhone 15 Pro', Product_attribute_list='features: A17 Pro chip, 120\u202fHz ProMotion display, USB‑C fast charging; dimensions: compact', material='titanium frame, Ceramic Shield glass', warranty='1‑year limited warranty'),
#  Pandas(Index=1, product_name='Samsung Galaxy S24 Ultra', Product_attribute_list='features: 200\u202fMP camera, S‑Pen support, 120\u202fHz AMOLED; sustainably sourced', material='Armor Aluminum frame, Gorilla Glass Victus', warranty='1‑year limited warranty'),
#  Pandas(Index=2, product_name='Google Pixel 8 Pro', Product_attribute_list='features: Tensor G3 chip, Magic Eraser, 50\u202fMP camera; rating: 4.7/5', material='matte glass back, aluminum frame', warranty='1‑year limited warranty'),
# ...
